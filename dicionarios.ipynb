# %%
import random

matriz_float = [[random.random() for _ in range(10)] for _ in range(5)]
matriz_int = [[random.randint(0, 9) for _ in range(4)] for _ in range(8)]

print("Matriz 5x10 (floats):")
for linha in matriz_float:
    print(linha)

print("\nMatriz 8x4 (inteiros):")
for linha in matriz_int:
    print(linha)
# Out:
# Matriz 5x10 (floats):
# [0.5046192253598063, 0.35446959011724355, 0.8604909086972361, 0.9184480294036235, 0.9133802192081213, 0.06353437973259324, 0.8160541200655905, 0.8752707596585846, 0.4933852216721777, 0.7156095725088732]
# [0.4175919000015511, 0.7546087004127822, 0.33532361078463935, 0.773085099919579, 0.17602103390376778, 0.3245183478263183, 0.7567946903853882, 0.08631885209105594, 0.848709693741672, 0.6310630016204282]
# [0.1663345439971029, 0.6274952371674141, 0.5653161516400796, 0.11373594406014687, 0.3267493378290228, 0.39582100931497366, 0.6086237442713899, 0.0804752320787272, 0.4377478875447517, 0.18024481763940925]
# [0.19093525852357118, 0.30807978541193004, 0.8590222502772541, 0.4030957394893605, 0.834658232001989, 0.17906825567244844, 0.648015168442328, 0.31270417530305983, 0.2727733177757985, 0.04474105429961106]
# [0.1012840406560761, 0.1753771414248395, 0.5726210953443863, 0.68004135345087, 0.43569778848635976, 0.35874656799870597, 0.668580117341507, 0.793516347679458, 0.5685372318425124, 0.8588308734196265]
#
# Matriz 8x4 (inteiros):
# [3, 0, 2, 3]
# [4, 1, 6, 5]
# [2, 3, 1, 9]
# [7, 2, 2, 7]
# [1, 4, 9, 4]
# [6, 2, 5, 7]
# [8, 6, 8, 9]
# [3, 9, 7, 9]
